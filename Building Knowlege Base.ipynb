# %% [markdown]
# # <span style="color:blue"> Building Knowledge Base</span>

# %%
# !pip install pinecone-client
# !pip install python-dotenv
# !pip install gensim nltk
# !pip install PyPDF2
# !pip install openai==0.28
import openai
print(openai.__version__)
import time
from time import sleep
import gensim
from gensim.models import Word2Vec
import nltk
nltk.download('punkt')
import numpy as np
from pinecone import Pinecone, PodSpec
from dotenv import load_dotenv
import os
from PyPDF2 import PdfReader
# Out:
# Requirement already satisfied: pinecone-client in /usr/local/lib/python3.10/dist-packages (3.0.2)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2024.2.2)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.9.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.0.7)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (3.0.1)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Create and connect a Pincone index
# Load environment variables from .env file
env = load_dotenv() # Copy .env file to the same directory before running

# Retrieve Pinecone API key from environment variables
pinecone_api_key = os.getenv("PINECONE_API_KEY")
# Retrieve OpenAI API key from environment variables
openai.api_key = os.getenv("OPENAI_API_KEY")

# initialize connection to pinecone (get API key at app.pinecone.io)
pc = Pinecone(api_key=pinecone_api_key, environment="us-west1-gcp-free")

# Specify the name of index
index_name = "cstugpt-kb"

# check if index already exists
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=1536,
        metric='cosine',
        spec=PodSpec(environment="us-west1-gcp", pod_type="p1.x1")
        #metadata_config={'indexed': ['cstu_id']} #indexed key in the dictionary specifies cstu_id column be indexed, means that the values in the column will be stored in a way that makes them faster to search
    )

# Connect to the Pinecone index
index = pc.Index(index_name)

# %%
# Buiding own embedding model based on Word2Vector
def tokenize_text(text):
    return nltk.word_tokenize(text)

# Train a Word2Vec model
def train_word2vec_model(tokens):
    model = Word2Vec(tokens, vector_size=1536, min_count=1)
    return model

# Generate an embedding for a text
def generate_embedding(model, text):
    tokens = nltk.word_tokenize(text)
    word_vectors = [model.wv[token] for token in tokens if token in model.wv]
    if not word_vectors: # If no valid word vectors are found, return a vector of zeros
        return np.zeros(model.vector_size)
    embedding = np.mean(word_vectors, axis=0)
    return embedding

# Specify knowledge base file and parameters
cstu_file = r"cstugpt_kb.pdf"

# Create a reader object for the knowledge base file
print("Knowledge base file name:", cstu_file)
reader = PdfReader(cstu_file)
page_len = len(reader.pages)
print("Length of the knowledge base file:", page_len)

# Extract text from each page and concatenate
doc = " "
for i in range(page_len):
    doc += reader.pages[i].extract_text()
    print("Page completed:", i)
doc = doc.splitlines()
doc = [line for line in doc if line.strip()]

# Train Word2Vec model on entire corpus
tokens = [tokenize_text(text) for text in doc]
model = Word2Vec(tokens, vector_size=1536, min_count=1)
model.save("CSTU-embedding-model.mdl")

# Set chunking and embedding parameters
count = 0
chunk_size = 3
stride = 1
cstu_id = "cstu-kb"

# Connect to Pinecone index
index = pc.Index(index_name)

# Iterate over the document in chunks and upsert embeddings to index
i_begin=0; # beginning of the chunk
while i_begin <= (len(doc) - chunk_size):
    i_end = min(len(doc), i_begin + chunk_size)
    doc_chunk = doc[i_begin:i_end]
    texts = ""
    for x in doc_chunk:
        texts += x
    print("The", count+1, "doc chunk text:", texts)
    print("==========================================================")
    # Create embeddings of the chunk texts
    # embed = np.mean([model.wv[token] for token in tokenize_text(texts) if token in model.wv], axis=0)
    embed = generate_embedding(model, texts)
    # print("Embeds length:", len(embed))

    # Prepare metadata
    metadata = {"cstu_id": cstu_id + '_' + str(count), "text": texts}
    count += 1

    # Upsert to Pinecone and corresponding namespace
    index.upsert(vectors=[(metadata["cstu_id"], embed, metadata)], namespace="cstu")
    i_begin += stride
# Out:
# Knowledge base file name: cstugpt_ka.pdf
# Length of the knowledge base file: 2
# Page completed: 0
# Page completed: 1
# The 1 doc chunk text:  California Science And Technology University (CSTU)  documents : Contact Email: admission@cstu.edu ; Contact Office: (408) 400 -3948;  Address: 1601 McCarthy Boulevard, Milpitas, CA 95035;  The president of CSTU  is Prof. Glen Qin.
# ==========================================================
# The 2 doc chunk text: Contact Email: admission@cstu.edu ; Contact Office: (408) 400 -3948;  Address: 1601 McCarthy Boulevard, Milpitas, CA 95035;  The president of CSTU  is Prof. Glen Qin.  CSTU offer s programs: Bachelor /Master  of Science in Computer Systems and Engineering,
# ==========================================================
# The 3 doc chunk text: Address: 1601 McCarthy Boulevard, Milpitas, CA 95035;  The president of CSTU  is Prof. Glen Qin.  CSTU offer s programs: Bachelor /Master  of Science in Computer Systems and Engineering, Bachelor of Science in Business Administration, Bachelor /Master of Business Administration and
# ==========================================================
# The 4 doc chunk text: The president of CSTU  is Prof. Glen Qin.  CSTU offer s programs: Bachelor /Master  of Science in Computer Systems and Engineering, Bachelor of Science in Business Administration, Bachelor /Master of Business Administration and Emerging Technology Training Program.
# ==========================================================
# The 5 doc chunk text: CSTU offer s programs: Bachelor /Master  of Science in Computer Systems and Engineering, Bachelor of Science in Business Administration, Bachelor /Master of Business Administration and Emerging Technology Training Program.  List of  courses  in Spring  2024: CSE642 -GenAI  by Prof. Sridharan M uthuswamy , CSE622 -Big
# ==========================================================
# The 6 doc chunk text: Bachelor of Science in Business Administration, Bachelor /Master of Business Administration and Emerging Technology Training Program.  List of  courses  in Spring  2024: CSE642 -GenAI  by Prof. Sridharan M uthuswamy , CSE622 -Big Data with Apache Spark  by Prof.  George Jen , CSE646 -AI for Industrial Application  by Prof.  Laiq
# ==========================================================
# The 7 doc chunk text: Emerging Technology Training Program.  List of  courses  in Spring  2024: CSE642 -GenAI  by Prof. Sridharan M uthuswamy , CSE622 -Big Data with Apache Spark  by Prof.  George Jen , CSE646 -AI for Industrial Application  by Prof.  Laiq Ahmad , CSE591 -Seminars  by  Prof.  Yong Feng , CSE600 -Python for AI  by Prof.  Glen Qin .
# ==========================================================
# The 8 doc chunk text: List of  courses  in Spring  2024: CSE642 -GenAI  by Prof. Sridharan M uthuswamy , CSE622 -Big Data with Apache Spark  by Prof.  George Jen , CSE646 -AI for Industrial Application  by Prof.  Laiq Ahmad , CSE591 -Seminars  by  Prof.  Yong Feng , CSE600 -Python for AI  by Prof.  Glen Qin . Additional information about GenAI class:
# ==========================================================
# The 9 doc chunk text: Data with Apache Spark  by Prof.  George Jen , CSE646 -AI for Industrial Application  by Prof.  Laiq Ahmad , CSE591 -Seminars  by  Prof.  Yong Feng , CSE600 -Python for AI  by Prof.  Glen Qin . Additional information about GenAI class:  -The email address of Prof.  Sridharan  is muthuswamy.sridharan@cstu.edu
# ==========================================================
# The 10 doc chunk text: Ahmad , CSE591 -Seminars  by  Prof.  Yong Feng , CSE600 -Python for AI  by Prof.  Glen Qin . Additional information about GenAI class:  -The email address of Prof.  Sridharan  is muthuswamy.sridharan@cstu.edu  -The class is held online and offline at CSTU campus.
# ==========================================================
# The 11 doc chunk text: Additional information about GenAI class:  -The email address of Prof.  Sridharan  is muthuswamy.sridharan@cstu.edu  -The class is held online and offline at CSTU campus.  -The time schedule for GenAI class is Monday from 7:30 pm to 9:30 pm and Saturday 09am to
# ==========================================================
# The 12 doc chunk text: -The email address of Prof.  Sridharan  is muthuswamy.sridharan@cstu.edu  -The class is held online and offline at CSTU campus.  -The time schedule for GenAI class is Monday from 7:30 pm to 9:30 pm and Saturday 09am to 10:30 am.
# ==========================================================
# The 13 doc chunk text: -The class is held online and offline at CSTU campus.  -The time schedule for GenAI class is Monday from 7:30 pm to 9:30 pm and Saturday 09am to 10:30 am.  - The GenAI project presentation day: Saturday, Feb 17, 2024.
# ==========================================================
# The 14 doc chunk text: -The time schedule for GenAI class is Monday from 7:30 pm to 9:30 pm and Saturday 09am to 10:30 am.  - The GenAI project presentation day: Saturday, Feb 17, 2024.  - The final day of GenAI class: Monday, Feb 20, 2024.
# ==========================================================
# The 15 doc chunk text: 10:30 am.  - The GenAI project presentation day: Saturday, Feb 17, 2024.  - The final day of GenAI class: Monday, Feb 20, 2024.  -The GenAI course offer 1.5 credit units.
# ==========================================================
# The 16 doc chunk text: - The GenAI project presentation day: Saturday, Feb 17, 2024.  - The final day of GenAI class: Monday, Feb 20, 2024.  -The GenAI course offer 1.5 credit units.  -The main topic of GenAI course is about overview of the important concepts, applications, and
# ==========================================================
# The 17 doc chunk text: - The final day of GenAI class: Monday, Feb 20, 2024.  -The GenAI course offer 1.5 credit units.  -The main topic of GenAI course is about overview of the important concepts, applications, and future of LLMs
# ==========================================================
# The 18 doc chunk text: -The GenAI course offer 1.5 credit units.  -The main topic of GenAI course is about overview of the important concepts, applications, and future of LLMs  - The detail list of topics or content of GenAI course:  Introducing the evolution of LLMs , Studying
# ==========================================================
# The 19 doc chunk text: -The main topic of GenAI course is about overview of the important concepts, applications, and future of LLMs  - The detail list of topics or content of GenAI course:  Introducing the evolution of LLMs , Studying the transformer architecture in sufficient depth , Learning the different kind of popular LLM
# ==========================================================
# The 20 doc chunk text: future of LLMs  - The detail list of topics or content of GenAI course:  Introducing the evolution of LLMs , Studying the transformer architecture in sufficient depth , Learning the different kind of popular LLM architectures built using transformers , Learning prompting and prompt engineering ,
# ==========================================================
# The 21 doc chunk text: - The detail list of topics or content of GenAI course:  Introducing the evolution of LLMs , Studying the transformer architecture in sufficient depth , Learning the different kind of popular LLM architectures built using transformers , Learning prompting and prompt engineering , Understanding the LLM scaling laws , Studying the different kinds of LLM fine -tuning techniques ,
# ==========================================================
# The 22 doc chunk text: the transformer architecture in sufficient depth , Learning the different kind of popular LLM architectures built using transformers , Learning prompting and prompt engineering , Understanding the LLM scaling laws , Studying the different kinds of LLM fine -tuning techniques , Exploring reinforcement learning from human feedback (RLHF) , Introducing LLM reasoning .
# ==========================================================
# The 23 doc chunk text: architectures built using transformers , Learning prompting and prompt engineering , Understanding the LLM scaling laws , Studying the different kinds of LLM fine -tuning techniques , Exploring reinforcement learning from human feedback (RLHF) , Introducing LLM reasoning .  - There are no specific text books for GenAI course. The instructor will share a few research papers
# ==========================================================
# The 24 doc chunk text: Understanding the LLM scaling laws , Studying the different kinds of LLM fine -tuning techniques , Exploring reinforcement learning from human feedback (RLHF) , Introducing LLM reasoning .  - There are no specific text books for GenAI course. The instructor will share a few research papers on specific topics.
# ==========================================================
# The 25 doc chunk text: Exploring reinforcement learning from human feedback (RLHF) , Introducing LLM reasoning .  - There are no specific text books for GenAI course. The instructor will share a few research papers on specific topics.  - The prerequisite of GenAI course is good understanding of machine learning and deep learning,
# ==========================================================
# The 26 doc chunk text: - There are no specific text books for GenAI course. The instructor will share a few research papers on specific topics.  - The prerequisite of GenAI course is good understanding of machine learning and deep learning, working experience with Python programming, basic computer concepts, business software
# ==========================================================
# The 27 doc chunk text: on specific topics.  - The prerequisite of GenAI course is good understanding of machine learning and deep learning, working experience with Python programming, basic computer concepts, business software tools.
# ==========================================================
# The 28 doc chunk text: - The prerequisite of GenAI course is good understanding of machine learning and deep learning, working experience with Python programming, basic computer concepts, business software tools.  - Learning methods: A combination of lectures, class participation, and hands -on work are used
# ==========================================================
# The 29 doc chunk text: working experience with Python programming, basic computer concepts, business software tools.  - Learning methods: A combination of lectures, class participation, and hands -on work are used to facilitate the learning.
# ==========================================================
# The 30 doc chunk text: tools.  - Learning methods: A combination of lectures, class participation, and hands -on work are used to facilitate the learning.  - Learning outcomes for students: Communication skills, Critical thinking abilities, Information
# ==========================================================
# The 31 doc chunk text: - Learning methods: A combination of lectures, class participation, and hands -on work are used to facilitate the learning.  - Learning outcomes for students: Communication skills, Critical thinking abilities, Information literacy, Proficiency in working with AI/Large Language Models (LLMs), Knowledge of LLM
# ==========================================================
# The 32 doc chunk text: to facilitate the learning.  - Learning outcomes for students: Communication skills, Critical thinking abilities, Information literacy, Proficiency in working with AI/Large Language Models (LLMs), Knowledge of LLM Prompt Engineering.
# ==========================================================
# The 33 doc chunk text: - Learning outcomes for students: Communication skills, Critical thinking abilities, Information literacy, Proficiency in working with AI/Large Language Models (LLMs), Knowledge of LLM Prompt Engineering.  - Students are expected to attend all classes, actively participate, and complete all assigned
# ==========================================================
# The 34 doc chunk text: literacy, Proficiency in working with AI/Large Language Models (LLMs), Knowledge of LLM Prompt Engineering.  - Students are expected to attend all classes, actively participate, and complete all assigned course work for all courses for which they are registered.
# ==========================================================
# The 35 doc chunk text: Prompt Engineering.  - Students are expected to attend all classes, actively participate, and complete all assigned course work for all courses for which they are registered.  - Evaluation Criteria & Grading Scale:  Homeworks: 30%, Quizzes: 30%, Final Project: 30%,
# ==========================================================
# The 36 doc chunk text: - Students are expected to attend all classes, actively participate, and complete all assigned course work for all courses for which they are registered.  - Evaluation Criteria & Grading Scale:  Homeworks: 30%, Quizzes: 30%, Final Project: 30%, Class Participation: 10%.
# ==========================================================
# The 37 doc chunk text: course work for all courses for which they are registered.  - Evaluation Criteria & Grading Scale:  Homeworks: 30%, Quizzes: 30%, Final Project: 30%, Class Participation: 10%.  (1) Master of Science in Computer Systems and Engineering  (MSCSE) : Reference : https://www.cstu.edu/pages/academic/programs/MSCSE.html?v=90709eed62
# ==========================================================
# The 38 doc chunk text: - Evaluation Criteria & Grading Scale:  Homeworks: 30%, Quizzes: 30%, Final Project: 30%, Class Participation: 10%.  (1) Master of Science in Computer Systems and Engineering  (MSCSE) : Reference : https://www.cstu.edu/pages/academic/programs/MSCSE.html?v=90709eed62  MSCSE Length: 24 Month , Include: 10 Courses , Semester Units: A minimum of 30 semester
# ==========================================================
# The 39 doc chunk text: Class Participation: 10%.  (1) Master of Science in Computer Systems and Engineering  (MSCSE) : Reference : https://www.cstu.edu/pages/academic/programs/MSCSE.html?v=90709eed62  MSCSE Length: 24 Month , Include: 10 Courses , Semester Units: A minimum of 30 semester units of graduate study are required .
# ==========================================================
# The 40 doc chunk text: (1) Master of Science in Computer Systems and Engineering  (MSCSE) : Reference : https://www.cstu.edu/pages/academic/programs/MSCSE.html?v=90709eed62  MSCSE Length: 24 Month , Include: 10 Courses , Semester Units: A minimum of 30 semester units of graduate study are required .   (2) Master of Business Administration (MBA) : Reference :
# ==========================================================
# The 41 doc chunk text: MSCSE Length: 24 Month , Include: 10 Courses , Semester Units: A minimum of 30 semester units of graduate study are required .   (2) Master of Business Administration (MBA) : Reference : https://www.cstu.edu/pages/academic/programs/MBA.html?v=152d5605f2
# ==========================================================
# The 42 doc chunk text: units of graduate study are required .   (2) Master of Business Administration (MBA) : Reference : https://www.cstu.edu/pages/academic/programs/MBA.html?v=152d5605f2  (3) Emerging Technology Training Program (ETTP) : Reference :
# ==========================================================
# The 43 doc chunk text: (2) Master of Business Administration (MBA) : Reference : https://www.cstu.edu/pages/academic/programs/MBA.html?v=152d5605f2  (3) Emerging Technology Training Program (ETTP) : Reference : https://www.cstu.edu/pages/academic/programs/ET.html?v=160c93f733 , ETTP  covers core
# ==========================================================
# The 44 doc chunk text: https://www.cstu.edu/pages/academic/programs/MBA.html?v=152d5605f2  (3) Emerging Technology Training Program (ETTP) : Reference : https://www.cstu.edu/pages/academic/programs/ET.html?v=160c93f733 , ETTP  covers core knowledge to Artificial Intelligence (AI), Big Data, Cloud Computing, Business Analytics, and other optional
# ==========================================================
# The 45 doc chunk text: (3) Emerging Technology Training Program (ETTP) : Reference : https://www.cstu.edu/pages/academic/programs/ET.html?v=160c93f733 , ETTP  covers core knowledge to Artificial Intelligence (AI), Big Data, Cloud Computing, Business Analytics, and other optional courses. Length: 8 Month , Include: 4 Courses , Semester Units: 12 .
# ==========================================================
# The 46 doc chunk text: https://www.cstu.edu/pages/academic/programs/ET.html?v=160c93f733 , ETTP  covers core knowledge to Artificial Intelligence (AI), Big Data, Cloud Computing, Business Analytics, and other optional courses. Length: 8 Month , Include: 4 Courses , Semester Units: 12 . Refer the following link for more information about the programs and courses at CSTU:
# ==========================================================
# The 47 doc chunk text: knowledge to Artificial Intelligence (AI), Big Data, Cloud Computing, Business Analytics, and other optional courses. Length: 8 Month , Include: 4 Courses , Semester Units: 12 . Refer the following link for more information about the programs and courses at CSTU: https://www.cstu.edu/pages/tmpl/Catalog.pdf
# ==========================================================
# The 48 doc chunk text: courses. Length: 8 Month , Include: 4 Courses , Semester Units: 12 . Refer the following link for more information about the programs and courses at CSTU: https://www.cstu.edu/pages/tmpl/Catalog.pdf     Refer the following link for academic policy at CSTU:
# ==========================================================
# The 49 doc chunk text: Refer the following link for more information about the programs and courses at CSTU: https://www.cstu.edu/pages/tmpl/Catalog.pdf     Refer the following link for academic policy at CSTU: www.cstu.edu/pages/academic/academic_policies/academic_01.html?v=425b0d574e
# ==========================================================

# %%
# Using OpenAI embedding model
embed_model = "text-embedding-ada-002"

# Specify knowledge base file and parameters
cstu_file = r"cstugpt_kb.pdf"

# Create a reader object for the knowledge base file
print("Knowledge base file name:", cstu_file)
reader = PdfReader(cstu_file)
page_len = len(reader.pages)
print("Length of the knowledge base file:", page_len)

# Extract text from each page and concatenate
doc = " "
for i in range(page_len):
    doc += reader.pages[i].extract_text()
    print("Page completed:", i)
doc = doc.splitlines()
doc = [line for line in doc if line.strip()]

# Set chunking and embedding parameters
count = 0
chunk_size = 3
stride = 1
cstu_id = "cstu-kb"

# Connect to Pinecone index
index = pc.Index(index_name)

# Iterate over the document in chunks and upsert embeddings to index
i_begin=0; # beginning of the chunk
while i_begin <= (len(doc) - chunk_size):
    i_end = min(len(doc), i_begin + chunk_size)
    doc_chunk = doc[i_begin:i_end]
    texts = ""
    for x in doc_chunk:
        texts += x
    print("The", count+1, "doc chunk text:", texts)
    print("==========================================================")

    try: res = openai.Embedding.create(input=texts, engine=embed_model)
    except:
            done = False
            while not done:
                sleep(5)
                try:
                    res = openai.Embedding.create(input=texts, engine=embed_model)
                    done = True
                except:
                    pass
    embed = res['data'][0]['embedding']

    # Prepare metadata
    metadata = {"cstu_id": cstu_id + '_' + str(count), "text": texts}
    count += 1

    # Upsert to Pinecone and corresponding namespace
    index.upsert(vectors=[(metadata["cstu_id"], embed, metadata)], namespace="cstu")
    i_begin += stride
# Out:
# Knowledge base file name: cstugpt_ka.pdf
# Length of the knowledge base file: 2
# Page completed: 0
# Page completed: 1
# The 1 doc chunk text:  California Science And Technology University (CSTU)  documents : Contact Email: admission@cstu.edu ; Contact Office: (408) 400 -3948;  Address: 1601 McCarthy Boulevard, Milpitas, CA 95035;
# ==========================================================
# The 2 doc chunk text: Contact Email: admission@cstu.edu ; Contact Office: (408) 400 -3948;  Address: 1601 McCarthy Boulevard, Milpitas, CA 95035;  The president of CSTU  is Prof. Glen Qin.
# ==========================================================
# The 3 doc chunk text: Address: 1601 McCarthy Boulevard, Milpitas, CA 95035;  The president of CSTU  is Prof. Glen Qin.  CSTU offer s programs: Bachelor /Master  of Science in Computer Systems and Engineering,
# ==========================================================
# The 4 doc chunk text: The president of CSTU  is Prof. Glen Qin.  CSTU offer s programs: Bachelor /Master  of Science in Computer Systems and Engineering, Bachelor of Science in Business Administration, Bachelor /Master of Business Administration and
# ==========================================================
# The 5 doc chunk text: CSTU offer s programs: Bachelor /Master  of Science in Computer Systems and Engineering, Bachelor of Science in Business Administration, Bachelor /Master of Business Administration and Emerging Technology Training Program.
# ==========================================================
# The 6 doc chunk text: Bachelor of Science in Business Administration, Bachelor /Master of Business Administration and Emerging Technology Training Program.  List of  courses  in Spring  2024: CSE642 -GenAI  by Prof. Sridharan M uthuswamy , CSE622 -Big
# ==========================================================
# The 7 doc chunk text: Emerging Technology Training Program.  List of  courses  in Spring  2024: CSE642 -GenAI  by Prof. Sridharan M uthuswamy , CSE622 -Big Data with Apache Spark  by Prof.  George Jen , CSE646 -AI for Industrial Application  by Prof.  Laiq
# ==========================================================
# The 8 doc chunk text: List of  courses  in Spring  2024: CSE642 -GenAI  by Prof. Sridharan M uthuswamy , CSE622 -Big Data with Apache Spark  by Prof.  George Jen , CSE646 -AI for Industrial Application  by Prof.  Laiq Ahmad , CSE591 -Seminars  by  Prof.  Yong Feng , CSE600 -Python for AI  by Prof.  Glen Qin .
# ==========================================================
# The 9 doc chunk text: Data with Apache Spark  by Prof.  George Jen , CSE646 -AI for Industrial Application  by Prof.  Laiq Ahmad , CSE591 -Seminars  by  Prof.  Yong Feng , CSE600 -Python for AI  by Prof.  Glen Qin . Additional information about GenAI class:
# ==========================================================
# The 10 doc chunk text: Ahmad , CSE591 -Seminars  by  Prof.  Yong Feng , CSE600 -Python for AI  by Prof.  Glen Qin . Additional information about GenAI class:  -The email address of Prof.  Sridharan  is muthuswamy.sridharan@cstu.edu
# ==========================================================
# The 11 doc chunk text: Additional information about GenAI class:  -The email address of Prof.  Sridharan  is muthuswamy.sridharan@cstu.edu  -The class is held online and offline at CSTU campus.
# ==========================================================
# The 12 doc chunk text: -The email address of Prof.  Sridharan  is muthuswamy.sridharan@cstu.edu  -The class is held online and offline at CSTU campus.  -The time schedule for GenAI class is Monday from 7:30 pm to 9:30 pm and Saturday 09am to
# ==========================================================
# The 13 doc chunk text: -The class is held online and offline at CSTU campus.  -The time schedule for GenAI class is Monday from 7:30 pm to 9:30 pm and Saturday 09am to 10:30 am.
# ==========================================================
# The 14 doc chunk text: -The time schedule for GenAI class is Monday from 7:30 pm to 9:30 pm and Saturday 09am to 10:30 am.  - The GenAI project presentation day: Saturday, Feb 17, 2024.
# ==========================================================
# The 15 doc chunk text: 10:30 am.  - The GenAI project presentation day: Saturday, Feb 17, 2024.  - The final day of GenAI class: Monday, Feb 20, 2024.
# ==========================================================
# The 16 doc chunk text: - The GenAI project presentation day: Saturday, Feb 17, 2024.  - The final day of GenAI class: Monday, Feb 20, 2024.  -The GenAI course offer 1.5 credit units.
# ==========================================================
# The 17 doc chunk text: - The final day of GenAI class: Monday, Feb 20, 2024.  -The GenAI course offer 1.5 credit units.  -The main topic of GenAI course is about overview of the important concepts, applications, and
# ==========================================================
# The 18 doc chunk text: -The GenAI course offer 1.5 credit units.  -The main topic of GenAI course is about overview of the important concepts, applications, and future of LLMs
# ==========================================================
# The 19 doc chunk text: -The main topic of GenAI course is about overview of the important concepts, applications, and future of LLMs  - The detail list of topics or content of GenAI course:  Introducing the evolution of LLMs , Studying
# ==========================================================
# The 20 doc chunk text: future of LLMs  - The detail list of topics or content of GenAI course:  Introducing the evolution of LLMs , Studying the transformer architecture in sufficient depth , Learning the different kind of popular LLM
# ==========================================================
# The 21 doc chunk text: - The detail list of topics or content of GenAI course:  Introducing the evolution of LLMs , Studying the transformer architecture in sufficient depth , Learning the different kind of popular LLM architectures built using transformers , Learning prompting and prompt engineering ,
# ==========================================================
# The 22 doc chunk text: the transformer architecture in sufficient depth , Learning the different kind of popular LLM architectures built using transformers , Learning prompting and prompt engineering , Understanding the LLM scaling laws , Studying the different kinds of LLM fine -tuning techniques ,
# ==========================================================
# The 23 doc chunk text: architectures built using transformers , Learning prompting and prompt engineering , Understanding the LLM scaling laws , Studying the different kinds of LLM fine -tuning techniques , Exploring reinforcement learning from human feedback (RLHF) , Introducing LLM reasoning .
# ==========================================================
# The 24 doc chunk text: Understanding the LLM scaling laws , Studying the different kinds of LLM fine -tuning techniques , Exploring reinforcement learning from human feedback (RLHF) , Introducing LLM reasoning .  - There are no specific text books for GenAI course. The instructor will share a few research papers
# ==========================================================
# The 25 doc chunk text: Exploring reinforcement learning from human feedback (RLHF) , Introducing LLM reasoning .  - There are no specific text books for GenAI course. The instructor will share a few research papers on specific topics.
# ==========================================================
# The 26 doc chunk text: - There are no specific text books for GenAI course. The instructor will share a few research papers on specific topics.  - The prerequisite of GenAI course is good understanding of machine learning and deep learning,
# ==========================================================
# The 27 doc chunk text: on specific topics.  - The prerequisite of GenAI course is good understanding of machine learning and deep learning, working experience with Python programming, basic computer concepts, business software
# ==========================================================
# The 28 doc chunk text: - The prerequisite of GenAI course is good understanding of machine learning and deep learning, working experience with Python programming, basic computer concepts, business software tools.
# ==========================================================
# The 29 doc chunk text: working experience with Python programming, basic computer concepts, business software tools.  - Learning methods: A combination of lectures, class participation, and hands -on work are used
# ==========================================================
# The 30 doc chunk text: tools.  - Learning methods: A combination of lectures, class participation, and hands -on work are used to facilitate the learning.
# ==========================================================
# The 31 doc chunk text: - Learning methods: A combination of lectures, class participation, and hands -on work are used to facilitate the learning.  - Learning outcomes for students: Communication skills, Critical thinking abilities, Information
# ==========================================================
# The 32 doc chunk text: to facilitate the learning.  - Learning outcomes for students: Communication skills, Critical thinking abilities, Information literacy, Proficiency in working with AI/Large Language Models (LLMs), Knowledge of LLM
# ==========================================================
# The 33 doc chunk text: - Learning outcomes for students: Communication skills, Critical thinking abilities, Information literacy, Proficiency in working with AI/Large Language Models (LLMs), Knowledge of LLM Prompt Engineering.
# ==========================================================
# The 34 doc chunk text: literacy, Proficiency in working with AI/Large Language Models (LLMs), Knowledge of LLM Prompt Engineering.  - Students are expected to attend all classes, actively participate, and complete all assigned
# ==========================================================
# The 35 doc chunk text: Prompt Engineering.  - Students are expected to attend all classes, actively participate, and complete all assigned course work for all courses for which they are registered.
# ==========================================================
# The 36 doc chunk text: - Students are expected to attend all classes, actively participate, and complete all assigned course work for all courses for which they are registered.  - Evaluation Criteria & Grading Scale:  Homeworks: 30%, Quizzes: 30%, Final Project: 30%,
# ==========================================================
# The 37 doc chunk text: course work for all courses for which they are registered.  - Evaluation Criteria & Grading Scale:  Homeworks: 30%, Quizzes: 30%, Final Project: 30%, Class Participation: 10%.
# ==========================================================
# The 38 doc chunk text: - Evaluation Criteria & Grading Scale:  Homeworks: 30%, Quizzes: 30%, Final Project: 30%, Class Participation: 10%.  (1) Master of Science in Computer Systems and Engineering  (MSCSE) : Reference : https://www.cstu.edu/pages/academic/programs/MSCSE.html?v=90709eed62
# ==========================================================
# The 39 doc chunk text: Class Participation: 10%.  (1) Master of Science in Computer Systems and Engineering  (MSCSE) : Reference : https://www.cstu.edu/pages/academic/programs/MSCSE.html?v=90709eed62  MSCSE Length: 24 Month , Include: 10 Courses , Semester Units: A minimum of 30 semester
# ==========================================================
# The 40 doc chunk text: (1) Master of Science in Computer Systems and Engineering  (MSCSE) : Reference : https://www.cstu.edu/pages/academic/programs/MSCSE.html?v=90709eed62  MSCSE Length: 24 Month , Include: 10 Courses , Semester Units: A minimum of 30 semester units of graduate study are required .
# ==========================================================
# The 41 doc chunk text: MSCSE Length: 24 Month , Include: 10 Courses , Semester Units: A minimum of 30 semester units of graduate study are required .   MSCSE c ourse list : CSE500 Software Design and Implementation , CSE520 Advanced Operating
# ==========================================================
# The 42 doc chunk text: units of graduate study are required .   MSCSE c ourse list : CSE500 Software Design and Implementation , CSE520 Advanced Operating System , CSE530 Big Data: Storage and Analysis , CSE540 Advanced Data Structure and
# ==========================================================
# The 43 doc chunk text: MSCSE c ourse list : CSE500 Software Design and Implementation , CSE520 Advanced Operating System , CSE530 Big Data: Storage and Analysis , CSE540 Advanced Data Structure and Algorithms , CSE544 Mobile Programming , CSE548 Artificial Intelligence , CSE550 Advanced
# ==========================================================
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-11-02cedf185a09> in <cell line: 32>()
#      40
# ---> 41     try: res = openai.Embedding.create(input=texts, engine=embed_model)
#      42     except:
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/embedding.py in create(cls, *args, **kwargs)
#      32             try:
# ---> 33                 response = super().create(*args, **kwargs)
#      34
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#
# /usr/local/lib/python3.10/dist-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     297         )
# --> 298         resp, got_stream = self._interpret_response(result, stream)
#     299         return resp, got_stream, self.api_key
#
# /usr/local/lib/python3.10/dist-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     699             return (
# --> 700                 self._interpret_response_line(
#     701                     result.content.decode("utf-8"),
#
# /usr/local/lib/python3.10/dist-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     764         if stream_error or not 200 <= rcode < 300:
# --> 765             raise self.handle_error_response(
#     766                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#
# RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-b7iXC5Q5FfD0vKFLGBQd6iQz on requests per min (RPM): Limit 3, Used 3, Requested 1. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-02cedf185a09> in <cell line: 32>()
#      43             done = False
#      44             while not done:
# ---> 45                 sleep(5)
#      46                 try:
#      47                     res = openai.Embedding.create(input=texts, engine=embed_model)
#
# KeyboardInterrupt:

# %%
# Checking knowledge base
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.00405,
#  'namespaces': {'cstu': {'vector_count': 405}},
#  'total_vector_count': 405}

# %%
# Checking knowledge base
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.00042,
#  'namespaces': {'cstu': {'vector_count': 42}},
#  'total_vector_count': 42}

# %%
# Unused codes
def mls_upsert(cstu_file, index_name, name_space, cstu_id, chunk_size, stride):
   # create a reader object
    print("Knowledge base file name:", cstu_file)
    reader = PdfReader(cstu_file)
    page_len = len(reader.pages)
    print("length of the knowledge base file:", page_len)
    doc = ""
    for i in range(page_len):
        doc += reader.pages[i].extract_text()
        print("page completed:", i)
    doc = doc.splitlines()
    # Train Word2Vec model on entire corpus
    tokens = [tokenize_text(text) for text in doc]
    model = train_word2vec_model(tokens)
    model.save("CSTU-embedding-model.mdl")
    #Connect to index
    index = pc.Index(index_name)
    count = 0
    for i in range(0, len(doc), chunk_size):#The loop iterates over the document in steps of chunk_size
        #find begining and end of the chunk
        i_begin = max(0, i-stride)
        i_end = min(len(doc), i_begin+chunk_size)
        doc_chunk = doc[i_begin:i_end]
        print("-------------------------------------------------------------")
        print("The ", i//chunk_size + 1, " doc chunk text:", doc_chunk)
        texts = ""
        for x in doc_chunk:
            texts += x
        print("Texts:", texts)

        #Create embeddings of the chunk texts
        embed = generate_embedding(model, texts)
        print("Embeds length:", len(embed))

        # Meta data preparation
        metadata = {
            "cstu_id": cstu_id + '_' + str(count),
            "text": texts
        }
        count += 1
        print("Upserted vector count is: ", count)
        print("==========================================================")

        #upsert to pinecone and corresponding namespace
        #index.upsert(vectors=[(metadata["cstu_id"], embed, metadata)], namespace=name_space)

mls_upsert(r"cstugpt_kb.pdf", "cstugpt-kb", "cstu","cstu-kb", 8, 1)
